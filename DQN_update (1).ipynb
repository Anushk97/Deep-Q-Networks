# %%
import random
import numpy as np
from collections import deque
from copy import deepcopy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque, namedtuple
import random

# Define the neural network architecture
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

class DQNAgent:
    def __init__(self, state_dim, action_dim, hidden_dim=128, buffer_size=10000, epsilon_decay = 0.99):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.hidden_dim = hidden_dim
        self.batch_size = 32
        self.buffer = deque(maxlen=buffer_size)
        self.gamma = 0.9
        #self.epsilon = 0.1
        self.dqn = DQN(state_dim, action_dim)
        self.target_dqn = deepcopy(self.dqn)
        self.optimizer = optim.Adam(self.dqn.parameters(), lr=0.001)

        self.epsilon = 0.5  # Start with higher epsilon
        self.epsilon_min = 0.1  # Minimum exploration rate
        self.epsilon_decay = epsilon_decay  # Decay factor

        # Additional attributes for prioritized experience replay
        self.alpha = 0.6  # Priority exponent
        self.beta = 0.4  # Importance sampling weight
        self.priorities = deque(maxlen=buffer_size)


    def choose_action(self, state, epsilon):
        if random.random() < epsilon:
            return random.randint(0, self.action_dim - 1)
        else:
            state = torch.FloatTensor(state)
            with torch.no_grad():
                q_values = self.dqn(state)
            return torch.argmax(q_values).item()

    def store(self, state, action, reward, next_state):
        self.buffer.append((state, action, reward, next_state))

    def train(self, batch_size):
        if len(self.buffer) < batch_size:
            return

        minibatch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states = zip(*minibatch)

        states = torch.stack([torch.FloatTensor(s) for s in states])
        actions = torch.LongTensor(actions)
        rewards = torch.FloatTensor(rewards)
        next_states = torch.stack([torch.FloatTensor(s) for s in next_states])

        current_q = self.dqn(states)
        current_q = current_q.gather(1, actions.unsqueeze(1)).squeeze(1)

        next_q = self.target_dqn(next_states).max(1)[0]
        targets = rewards + self.gamma * next_q

        loss = nn.MSELoss()(current_q, targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def update_target_net(self):
        self.target_dqn.load_state_dict(self.dqn.state_dict())

    def update_epsilon(self):
      self.epsilon = max(self.epsilon * self.epsilon_decay, self.epsilon_min)

    # Fine-Tuning Epsilon
    def fine_tune_epsilon(self, epsilon_value):
        self.epsilon = epsilon_value

# %%
class Car:
  def __init__(self, tyre="Intermediate"):
    self.default_tyre = tyre
    self.possible_tyres = ["Ultrasoft", "Soft", "Intermediate", "Fullwet"]
    self.pitstop_time = 23
    self.reset()
    # missing self.condition?


  def reset(self):
    self.change_tyre(self.default_tyre)


  def degrade(self, w, r):
    if self.tyre == "Ultrasoft":
        self.condition *= (1 - 0.0050*w - (2500-r)/90000)
    elif self.tyre == "Soft":
        self.condition *= (1 - 0.0051*w - (2500-r)/93000)
    elif self.tyre == "Intermediate":
        self.condition *= (1 - 0.0052*abs(0.5-w) - (2500-r)/95000)
    elif self.tyre == "Fullwet":
        self.condition *= (1 - 0.0053*(1-w) - (2500-r)/97000)


  def change_tyre(self, new_tyre):
    assert new_tyre in self.possible_tyres
    self.tyre = new_tyre
    self.condition = 1.00


  def get_velocity(self):
    if self.tyre == "Ultrasoft":
        vel = 80.7*(0.2 + 0.8*self.condition**1.5)
    elif self.tyre == "Soft":
        vel = 80.1*(0.2 + 0.8*self.condition**1.5)
    elif self.tyre == "Intermediate":
        vel = 79.5*(0.2 + 0.8*self.condition**1.5)
    elif self.tyre == "Fullwet":
        vel = 79.0*(0.2 + 0.8*self.condition**1.5)
    return vel

  def tyre_degrade(self, tyre, tyre_cond, w, r):
    if tyre == "Ultrasoft":
        tyre_cond *= (1 - 0.0050*w - (2500-r)/90000)
    elif tyre == "Soft":
        tyre_cond *= (1 - 0.0051*w - (2500-r)/93000)
    elif tyre == "Intermediate":
        tyre_cond *= (1 - 0.0052*abs(0.5-w) - (2500-r)/95000)
    elif tyre == "Fullwet":
        tyre_cond *= (1 - 0.0053*(1-w) - (2500-r)/97000)
    return tyre_cond

  def retrieve_velocity(self, tyre, tyre_cond):
    if tyre == "Ultrasoft":
        vel = 80.7*(0.2 + 0.8*tyre_cond**1.5)
    elif tyre == "Soft":
        vel = 80.1*(0.2 + 0.8*tyre_cond**1.5)
    elif tyre == "Intermediate":
        vel = 79.5*(0.2 + 0.8*tyre_cond**1.5)
    elif tyre == "Fullwet":
        vel = 79.0*(0.2 + 0.8*tyre_cond**1.5)
    return vel

class Track:
  def __init__(self, car=Car()):
    # self.radius and self.cur_weather are defined in self.reset()
    self.total_laps = 162
    self.car = car
    self.possible_weather = ["Dry", "20% Wet", "40% Wet", "60% Wet", "80% Wet", "100% Wet"]
    self.wetness = {
        "Dry": 0.00, "20% Wet": 0.20, "40% Wet": 0.40, "60% Wet": 0.60, "80% Wet": 0.80, "100% Wet": 1.00
    }
    self.p_transition = {
        "Dry": {
            "Dry": 0.987, "20% Wet": 0.013, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
        },
        "20% Wet": {
            "Dry": 0.012, "20% Wet": 0.975, "40% Wet": 0.013, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
        },
        "40% Wet": {
            "Dry": 0.000, "20% Wet": 0.012, "40% Wet": 0.975, "60% Wet": 0.013, "80% Wet": 0.000, "100% Wet": 0.000
        },
        "60% Wet": {
            "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.012, "60% Wet": 0.975, "80% Wet": 0.013, "100% Wet": 0.000
        },
        "80% Wet": {
            "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.012, "80% Wet": 0.975, "100% Wet": 0.013
        },
        "100% Wet": {
            "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.012, "100% Wet": 0.988
        }
    }
    self.reset()


  def reset(self):
    # self.radius = np.random.randint(600,1201)
    self.radius = np.random.randint(600,601)
    # self.radius = np.random.randint(900,901)
    # self.radius = np.random.randint(1200,1201)
    self.cur_weather = np.random.choice(self.possible_weather)
    self.is_done = False
    self.pitstop = False
    self.laps_cleared = 0
    self.car.reset()
    return self._get_state()


  def _get_state(self):
    tyre_encoding = [0] * len(self.car.possible_tyres)
    tyre_index = self.car.possible_tyres.index(self.car.tyre)
    tyre_encoding[tyre_index] = 1

  # One-hot encoding for weather condition
    weather_encoding = [0] * len(self.possible_weather)
    weather_index = self.possible_weather.index(self.cur_weather)
    weather_encoding[weather_index] = 1

  # Combine the encoded vectors with the remaining state variables
    return tyre_encoding + [self.car.condition] + weather_encoding + [self.radius, self.laps_cleared]


  def transition(self, action=0):
    time_taken = 0
    if self.laps_cleared == int(self.laps_cleared):
        if self.pitstop:
            self.car.change_tyre(self.committed_tyre)
            time_taken += self.car.pitstop_time
            self.pitstop = False

    ## The environment is coded such that only an action taken at
    # the start of the three-quarters mark of each lap matters
    if self.laps_cleared - int(self.laps_cleared) == 0.75:
        if action < 4:
            self.pitstop = True
            self.committed_tyre = self.car.possible_tyres[action]
        else:
            self.pitstop = False

    self.cur_weather = np.random.choice(
        self.possible_weather, p=list(self.p_transition[self.cur_weather].values())
    )
    # we assume that degradation happens only after a car has travelled the one-eighth lap
    velocity = self.car.get_velocity()
    time_taken += (2*np.pi*self.radius/8) / velocity
    reward = 0 - time_taken
    self.car.degrade(
        w=self.wetness[self.cur_weather], r=self.radius
    )
    self.laps_cleared += 0.125

    if self.laps_cleared == self.total_laps:
        self.is_done = True

    next_state = self._get_state()
    return reward, next_state, self.is_done, velocity

# %%
class Agent():
  def __init__(self, state_dim, action_dim, hidden_dim=128, buffer_size=10000, epsilon_decay = 0.99):
    # ... (The original attributes and methods you provided)
    self.possible_weather = ["Dry", "20% Wet", "40% Wet", "60% Wet", "80% Wet", "100% Wet"]
    self.wetness = {
        "Dry": 0.00, "20% Wet": 0.20, "40% Wet": 0.40, "60% Wet": 0.60, "80% Wet": 0.80, "100% Wet": 1.00
    }
    self.possible_tyres = ["Ultrasoft", "Soft", "Intermediate", "Fullwet"]
    self.pitstop_time = 23


    #self.scheduler = StepLR(self.optimizer, step_size=100, gamma=0.95)
    self.table = {"Ultrasoft": {
                                "Dry": {'condition':0,'time':0},
                                "20% Wet": {'condition':0,'time':0},
                                "40% Wet": {'condition':0,'time':0},
                                "60% Wet": {'condition':0,'time':0},
                                "80% Wet": {'condition':0,'time':0},
                                "100% Wet": {'condition':0,'time':0}
                                },
                      "Soft":  {
                                "Dry": {'condition':0,'time':0},
                                "20% Wet": {'condition':0,'time':0},
                                "40% Wet": {'condition':0,'time':0},
                                "60% Wet": {'condition':0,'time':0},
                                "80% Wet": {'condition':0,'time':0},
                                "100% Wet": {'condition':0,'time':0}
                                },
              "Intermediate":  {
                                "Dry": {'condition':0,'time':0},
                                "20% Wet": {'condition':0,'time':0},
                                "40% Wet": {'condition':0,'time':0},
                                "60% Wet": {'condition':0,'time':0},
                                "80% Wet": {'condition':0,'time':0},
                                "100% Wet": {'condition':0,'time':0}
                                },
                  "Fullwet":   {
                                "Dry": {'condition':0,'time':0},
                                "20% Wet": {'condition':0,'time':0},
                                "40% Wet": {'condition':0,'time':0},
                                "60% Wet": {'condition':0,'time':0},
                                "80% Wet": {'condition':0,'time':0},
                                "100% Wet": {'condition':0,'time':0}
                                },
                  "Unchanged": {
                                "Dry": {'condition':0,'time':0},
                                "20% Wet": {'condition':0,'time':0},
                                "40% Wet": {'condition':0,'time':0},
                                "60% Wet": {'condition':0,'time':0},
                                "80% Wet": {'condition':0,'time':0},
                                "100% Wet": {'condition':0,'time':0}}
                  }
    # self.generate_lap_table(state)


    # Initialize DQN agent
    #self.dqn_agent = DQNAgent(state_dim, action_dim, buffer_size)
    self.dqn_agent = DQNAgent(state_dim, action_dim, buffer_size, hidden_dim)

  #action selection based on current state
  def choose_action(self, state, epsilon):
      # Extract tire condition from state
      tire_condition_index = len(self.possible_tyres)
      tire_condition = state[tire_condition_index]

      # If tire condition is below a threshold and there are more than a certain number of laps remaining
      if tire_condition < 0.3 and state[-1] < 146:  # Assuming 16 laps remaining out of 162
          return 4  # Action to take a pit stop

      return self.dqn_agent.choose_action(state, epsilon)

  #maintain replay buffer to train the agent later
  def store(self, state, action, reward, next_state):
    self.dqn_agent.store(state, action, reward, next_state)

  # samples a batch of experiences from the replay buffer and updates the network's weights based on the difference between predicted and target Q-values.
  def train(self, batch_size):
    tyre_condition_index = len(self.possible_tyres)
    return self.dqn_agent.train(batch_size,tyre_condition_index=tyre_condition_index)

  # stabalize learning process
  def update_target_net(self):
    self.dqn_agent.update_target_net()

  # Gradual Decay of Epsilon
  def update_epsilon(self):
      self.dqn_agent.update_epsilon()

  # Fine-Tuning Epsilon
  def fine_tune_epsilon(self, epsilon_value):
      self.dqn_agent.fine_tune_epsilon()

  # Adjust Learning Rate
  def adjust_learning_rate(self, learning_rate):
      self.dqn_agent.adjust_learning_rate()

# %%
# Training loop
def train_agent(agent, env, episodes):
    for episode in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            epsilon = max(agent.epsilon, 0.5)  # Ensure epsilon doesn't drop below 0.1
            action = agent.choose_action(state, epsilon)
            reward, next_state, done, _ = env.transition(action)
            agent.store(state, action, reward, next_state)
            loss = agent.train(agent.batch_size)
            state = next_state
            total_reward += reward

        agent.update_target_net()
        agent.fine_tune_epsilon(0.1)  # Example: Set epsilon to 0.1

        # Adjust learning rate if needed
        #agent.adjust_learning_rate(0.001)
        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward:.2f}, Loss: {loss:.6f}")

# Create the environment and agent
car = Car()
track = Track(car)
state_dim = len(track._get_state())
action_dim = len(car.possible_tyres) + 1  # Actions are changing tires or not

agent = DQNAgent(state_dim, action_dim)

# Train the agent
train_agent(agent, track, episodes=500)
# Out:
# Episode 1/500, Total Reward: -11913.41, Loss: 43.401142
# Episode 2/500, Total Reward: -12283.98, Loss: 65.761673
# Episode 3/500, Total Reward: -12012.98, Loss: 40.700954
# Episode 4/500, Total Reward: -11861.28, Loss: 16.578018
# Episode 5/500, Total Reward: -12027.50, Loss: 20.864088
# Episode 6/500, Total Reward: -11842.16, Loss: 41.305531
# Episode 7/500, Total Reward: -12145.03, Loss: 30.883251
# Episode 8/500, Total Reward: -11827.64, Loss: 3.859449
# Episode 9/500, Total Reward: -11854.95, Loss: 41.259083
# Episode 10/500, Total Reward: -11854.22, Loss: 39.711834
# Episode 11/500, Total Reward: -11958.66, Loss: 30.236134
# Episode 12/500, Total Reward: -11828.67, Loss: 43.321186
# Episode 13/500, Total Reward: -11848.55, Loss: 29.798222
# Episode 14/500, Total Reward: -11811.98, Loss: 51.591564
# Episode 15/500, Total Reward: -12030.93, Loss: 5.088189
# Episode 16/500, Total Reward: -11936.31, Loss: 27.611074
# Episode 17/500, Total Reward: -11796.57, Loss: 37.523064
# Episode 18/500, Total Reward: -11925.91, Loss: 51.365452
# Episode 19/500, Total Reward: -11935.93, Loss: 39.354336
# Episode 20/500, Total Reward: -11888.28, Loss: 52.239204
# Episode 21/500, Total Reward: -11871.94, Loss: 36.628391
# Episode 22/500, Total Reward: -12037.96, Loss: 25.564123
# Episode 23/500, Total Reward: -11998.96, Loss: 29.733662
# Episode 24/500, Total Reward: -11884.34, Loss: 39.589737
# Episode 25/500, Total Reward: -11916.80, Loss: 39.276218
# Episode 26/500, Total Reward: -12144.69, Loss: 11.253436
# Episode 27/500, Total Reward: -11980.63, Loss: 29.563305
# Episode 28/500, Total Reward: -11967.67, Loss: 18.714777
# Episode 29/500, Total Reward: -11974.82, Loss: 26.919842
# Episode 30/500, Total Reward: -11974.98, Loss: 16.668610
# Episode 31/500, Total Reward: -11904.65, Loss: 12.582436
# Episode 32/500, Total Reward: -11986.74, Loss: 18.187717
# Episode 33/500, Total Reward: -12010.92, Loss: 6.614092
# Episode 34/500, Total Reward: -12060.29, Loss: 10.151953
# Episode 35/500, Total Reward: -12343.64, Loss: 15.695365
# Episode 36/500, Total Reward: -12252.56, Loss: 8.240780
# Episode 37/500, Total Reward: -12142.20, Loss: 0.766925
# Episode 38/500, Total Reward: -12379.05, Loss: 7.955953
# Episode 39/500, Total Reward: -11966.70, Loss: 8.806026
# Episode 40/500, Total Reward: -11985.00, Loss: 37.852654
# Episode 41/500, Total Reward: -12012.85, Loss: 15.366435
# Episode 42/500, Total Reward: -11992.11, Loss: 1.421123
# Episode 43/500, Total Reward: -11960.02, Loss: 13.017292
# Episode 44/500, Total Reward: -11907.41, Loss: 13.698553
# Episode 45/500, Total Reward: -11933.34, Loss: 7.820746
# Episode 46/500, Total Reward: -11799.21, Loss: 6.161964
# Episode 47/500, Total Reward: -11865.22, Loss: 4.638347
# Episode 48/500, Total Reward: -11996.61, Loss: 6.934492
# Episode 49/500, Total Reward: -11955.64, Loss: 2.920705
# Episode 50/500, Total Reward: -12073.40, Loss: 21.182211
# Episode 51/500, Total Reward: -11927.01, Loss: 2.922352
# Episode 52/500, Total Reward: -11785.09, Loss: 7.592461
# Episode 53/500, Total Reward: -12150.74, Loss: 6.239431
# Episode 54/500, Total Reward: -12060.68, Loss: 4.499594
# Episode 55/500, Total Reward: -11908.03, Loss: 12.019129
# Episode 56/500, Total Reward: -11871.08, Loss: 10.004622
# Episode 57/500, Total Reward: -11874.68, Loss: 7.942666
# Episode 58/500, Total Reward: -11916.13, Loss: 16.614254
# Episode 59/500, Total Reward: -11880.56, Loss: 14.849481
# Episode 60/500, Total Reward: -11975.67, Loss: 9.296964
# Episode 61/500, Total Reward: -12254.24, Loss: 5.899174
# Episode 62/500, Total Reward: -11993.19, Loss: 40.400387
# Episode 63/500, Total Reward: -12025.24, Loss: 12.555964
# Episode 64/500, Total Reward: -11893.83, Loss: 13.815329
# Episode 65/500, Total Reward: -11801.11, Loss: 18.832432
# Episode 66/500, Total Reward: -12172.27, Loss: 8.755607
# Episode 67/500, Total Reward: -11855.16, Loss: 8.651922
# Episode 68/500, Total Reward: -11814.64, Loss: 10.776264
# Episode 69/500, Total Reward: -11913.71, Loss: 8.961812
# Episode 70/500, Total Reward: -12124.60, Loss: 3.680463
# Episode 71/500, Total Reward: -11815.20, Loss: 4.042284
# Episode 72/500, Total Reward: -11902.40, Loss: 4.001865
# Episode 73/500, Total Reward: -11977.37, Loss: 8.530735
# Episode 74/500, Total Reward: -11870.57, Loss: 8.045558
# Episode 75/500, Total Reward: -11816.16, Loss: 8.225149
# Episode 76/500, Total Reward: -11927.52, Loss: 8.749255
# Episode 77/500, Total Reward: -11895.11, Loss: 7.941476
# Episode 78/500, Total Reward: -12051.49, Loss: 7.148738
# Episode 79/500, Total Reward: -12006.68, Loss: 3.359177
# Episode 80/500, Total Reward: -11956.01, Loss: 8.989342
# Episode 81/500, Total Reward: -11869.86, Loss: 1.170649
# Episode 82/500, Total Reward: -11914.03, Loss: 12.457718
# Episode 83/500, Total Reward: -11930.03, Loss: 20.118856
# Episode 84/500, Total Reward: -11892.76, Loss: 12.538092
# Episode 85/500, Total Reward: -12006.70, Loss: 4.359806
# Episode 86/500, Total Reward: -12068.89, Loss: 9.396999
# Episode 87/500, Total Reward: -11942.54, Loss: 9.156011
# Episode 88/500, Total Reward: -11997.58, Loss: 18.631945
# Episode 89/500, Total Reward: -12139.00, Loss: 0.611716
# Episode 90/500, Total Reward: -11899.17, Loss: 26.214796
# Episode 91/500, Total Reward: -11949.39, Loss: 13.280569
# Episode 92/500, Total Reward: -11967.61, Loss: 10.966930
# Episode 93/500, Total Reward: -12182.98, Loss: 10.780777
# Episode 94/500, Total Reward: -11916.45, Loss: 8.416229
# Episode 95/500, Total Reward: -11989.11, Loss: 3.308423
# Episode 96/500, Total Reward: -11875.81, Loss: 13.278747
# Episode 97/500, Total Reward: -11846.45, Loss: 10.823848
# Episode 98/500, Total Reward: -11980.76, Loss: 6.892386
# Episode 99/500, Total Reward: -11984.29, Loss: 14.369490
# Episode 100/500, Total Reward: -11992.96, Loss: 3.591931
# Episode 101/500, Total Reward: -11936.31, Loss: 7.230268
# Episode 102/500, Total Reward: -12030.42, Loss: 7.434417
# Episode 103/500, Total Reward: -12221.49, Loss: 4.023559
# Episode 104/500, Total Reward: -11845.30, Loss: 12.256209
# Episode 105/500, Total Reward: -12066.54, Loss: 2.710233
# Episode 106/500, Total Reward: -11839.23, Loss: 12.995453
# Episode 107/500, Total Reward: -11902.62, Loss: 1.913973
# Episode 108/500, Total Reward: -12001.22, Loss: 8.076326
# Episode 109/500, Total Reward: -11912.93, Loss: 10.548285
# Episode 110/500, Total Reward: -11984.19, Loss: 11.202474
# Episode 111/500, Total Reward: -11900.80, Loss: 0.495194
# Episode 112/500, Total Reward: -11943.34, Loss: 5.425794
# Episode 113/500, Total Reward: -11954.14, Loss: 3.088874
# Episode 114/500, Total Reward: -11826.04, Loss: 6.813589
# Episode 115/500, Total Reward: -12105.39, Loss: 5.421592
# Episode 116/500, Total Reward: -11773.47, Loss: 15.869179
# Episode 117/500, Total Reward: -11887.68, Loss: 4.282493
# Episode 118/500, Total Reward: -11884.61, Loss: 8.563639
# Episode 119/500, Total Reward: -11995.55, Loss: 4.840447
# Episode 120/500, Total Reward: -11858.73, Loss: 4.095225
# Episode 121/500, Total Reward: -11968.91, Loss: 3.331530
# Episode 122/500, Total Reward: -12043.99, Loss: 9.825983
# Episode 123/500, Total Reward: -11974.29, Loss: 4.312127
# Episode 124/500, Total Reward: -11882.67, Loss: 4.577535
# Episode 125/500, Total Reward: -11944.49, Loss: 10.654043
# Episode 126/500, Total Reward: -11849.98, Loss: 5.860022
# Episode 127/500, Total Reward: -11877.93, Loss: 4.782975
# Episode 128/500, Total Reward: -11918.78, Loss: 14.319323
# Episode 129/500, Total Reward: -12176.51, Loss: 8.132450
# Episode 130/500, Total Reward: -11851.35, Loss: 6.315150
# Episode 131/500, Total Reward: -11993.26, Loss: 5.820705
# Episode 132/500, Total Reward: -11933.14, Loss: 13.024998
# Episode 133/500, Total Reward: -11971.19, Loss: 3.546264
# Episode 134/500, Total Reward: -11822.06, Loss: 3.949380
# Episode 135/500, Total Reward: -11974.87, Loss: 9.432539
# Episode 136/500, Total Reward: -12223.08, Loss: 12.324296
# Episode 137/500, Total Reward: -11869.92, Loss: 11.784452
# Episode 138/500, Total Reward: -11976.52, Loss: 0.845776
# Episode 139/500, Total Reward: -11874.39, Loss: 8.512944
# Episode 140/500, Total Reward: -11992.46, Loss: 9.132409
# Episode 141/500, Total Reward: -11857.20, Loss: 10.190086
# Episode 142/500, Total Reward: -11951.29, Loss: 9.361028
# Episode 143/500, Total Reward: -11867.98, Loss: 32.822994
# Episode 144/500, Total Reward: -12084.36, Loss: 9.061506
# Episode 145/500, Total Reward: -12003.89, Loss: 16.505468
# Episode 146/500, Total Reward: -11905.42, Loss: 8.109049
# Episode 147/500, Total Reward: -11875.46, Loss: 24.747694
# Episode 148/500, Total Reward: -11911.17, Loss: 3.549598
# Episode 149/500, Total Reward: -11995.07, Loss: 19.610998
# Episode 150/500, Total Reward: -12278.50, Loss: 11.047060
# Episode 151/500, Total Reward: -11775.52, Loss: 1.916358
# Episode 152/500, Total Reward: -12002.16, Loss: 13.691473
# Episode 153/500, Total Reward: -11881.30, Loss: 3.634593
# Episode 154/500, Total Reward: -11886.73, Loss: 3.084444
# Episode 155/500, Total Reward: -12064.59, Loss: 11.857070
# Episode 156/500, Total Reward: -11941.22, Loss: 7.137220
# Episode 157/500, Total Reward: -11922.82, Loss: 7.772588
# Episode 158/500, Total Reward: -11895.23, Loss: 4.871889
# Episode 159/500, Total Reward: -12063.60, Loss: 11.880158
# Episode 160/500, Total Reward: -11852.78, Loss: 24.212360
# Episode 161/500, Total Reward: -11930.90, Loss: 18.883186
# Episode 162/500, Total Reward: -11964.28, Loss: 11.975913
# Episode 163/500, Total Reward: -11883.26, Loss: 8.522567
# Episode 164/500, Total Reward: -11804.04, Loss: 6.677262
# Episode 165/500, Total Reward: -11959.82, Loss: 7.039528
# Episode 166/500, Total Reward: -11927.02, Loss: 6.473093
# Episode 167/500, Total Reward: -11702.84, Loss: 6.830210
# Episode 168/500, Total Reward: -11814.76, Loss: 3.122646
# Episode 169/500, Total Reward: -11935.72, Loss: 3.714788
# Episode 170/500, Total Reward: -12070.46, Loss: 24.016996
# Episode 171/500, Total Reward: -12061.93, Loss: 17.695562
# Episode 172/500, Total Reward: -11819.43, Loss: 11.642702
# Episode 173/500, Total Reward: -11899.17, Loss: 16.906944
# Episode 174/500, Total Reward: -12099.07, Loss: 7.310606
# Episode 175/500, Total Reward: -11806.53, Loss: 8.270654
# Episode 176/500, Total Reward: -11888.92, Loss: 17.368347
# Episode 177/500, Total Reward: -12149.17, Loss: 4.921765
# Episode 178/500, Total Reward: -11901.89, Loss: 5.595726
# Episode 179/500, Total Reward: -11950.32, Loss: 6.564613
# Episode 180/500, Total Reward: -11942.82, Loss: 3.953887
# Episode 181/500, Total Reward: -12024.58, Loss: 23.757580
# Episode 182/500, Total Reward: -11866.06, Loss: 14.475757
# Episode 183/500, Total Reward: -11913.63, Loss: 8.860195
# Episode 184/500, Total Reward: -12062.23, Loss: 7.258608
# Episode 185/500, Total Reward: -11903.98, Loss: 19.929176
# Episode 186/500, Total Reward: -12219.84, Loss: 4.353255
# Episode 187/500, Total Reward: -11886.25, Loss: 3.405574
# Episode 188/500, Total Reward: -11941.34, Loss: 22.856592
# Episode 189/500, Total Reward: -11929.97, Loss: 2.506018
# Episode 190/500, Total Reward: -11918.50, Loss: 12.407623
# Episode 191/500, Total Reward: -11910.08, Loss: 6.563735
# Episode 192/500, Total Reward: -11823.33, Loss: 9.270818
# Episode 193/500, Total Reward: -12074.51, Loss: 7.223915
# Episode 194/500, Total Reward: -11933.80, Loss: 8.248698
# Episode 195/500, Total Reward: -12020.32, Loss: 4.321223
# Episode 196/500, Total Reward: -11988.73, Loss: 3.020133
# Episode 197/500, Total Reward: -11900.54, Loss: 8.532412
# Episode 198/500, Total Reward: -11868.53, Loss: 10.552872
# Episode 199/500, Total Reward: -11884.38, Loss: 2.795614
# Episode 200/500, Total Reward: -12020.20, Loss: 5.889272
# Episode 201/500, Total Reward: -12024.84, Loss: 8.467501
# Episode 202/500, Total Reward: -11929.98, Loss: 23.896444
# Episode 203/500, Total Reward: -11902.22, Loss: 6.094488
# Episode 204/500, Total Reward: -12011.36, Loss: 19.896914
# Episode 205/500, Total Reward: -11937.89, Loss: 13.970171
# Episode 206/500, Total Reward: -11931.15, Loss: 3.618905
# Episode 207/500, Total Reward: -11963.91, Loss: 11.003960
# Episode 208/500, Total Reward: -11964.92, Loss: 15.681753
# Episode 209/500, Total Reward: -12090.74, Loss: 6.511906
# Episode 210/500, Total Reward: -11897.14, Loss: 12.069446
# Episode 211/500, Total Reward: -12007.77, Loss: 5.893073
# Episode 212/500, Total Reward: -12017.78, Loss: 7.983753
# Episode 213/500, Total Reward: -11807.04, Loss: 0.230225
# Episode 214/500, Total Reward: -11848.13, Loss: 14.572121
# Episode 215/500, Total Reward: -12051.03, Loss: 0.259848
# Episode 216/500, Total Reward: -11966.73, Loss: 4.252864
# Episode 217/500, Total Reward: -11931.91, Loss: 3.665836
# Episode 218/500, Total Reward: -12026.09, Loss: 1.051668
# Episode 219/500, Total Reward: -11871.17, Loss: 0.356036
# Episode 220/500, Total Reward: -11960.87, Loss: 2.801612
# Episode 221/500, Total Reward: -11938.67, Loss: 9.034637
# Episode 222/500, Total Reward: -11820.63, Loss: 14.936134
# Episode 223/500, Total Reward: -12254.58, Loss: 8.514936
# Episode 224/500, Total Reward: -11818.03, Loss: 12.964342
# Episode 225/500, Total Reward: -11913.77, Loss: 19.609671
# Episode 226/500, Total Reward: -11943.52, Loss: 6.737365
# Episode 227/500, Total Reward: -11989.07, Loss: 6.466983
# Episode 228/500, Total Reward: -11961.90, Loss: 15.832701
# Episode 229/500, Total Reward: -11886.57, Loss: 6.957786
# Episode 230/500, Total Reward: -12484.88, Loss: 14.953948
# Episode 231/500, Total Reward: -12041.35, Loss: 6.597208
# Episode 232/500, Total Reward: -11961.12, Loss: 23.217007
# Episode 233/500, Total Reward: -11850.49, Loss: 9.267198
# Episode 234/500, Total Reward: -11732.22, Loss: 6.205142
# Episode 235/500, Total Reward: -12162.47, Loss: 8.589533
# Episode 236/500, Total Reward: -12014.28, Loss: 21.840839
# Episode 237/500, Total Reward: -11935.53, Loss: 10.244811
# Episode 238/500, Total Reward: -11931.67, Loss: 25.132648
# Episode 239/500, Total Reward: -11990.55, Loss: 8.052412
# Episode 240/500, Total Reward: -11978.41, Loss: 6.639677
# Episode 241/500, Total Reward: -11970.46, Loss: 7.378309
# Episode 242/500, Total Reward: -11943.93, Loss: 3.673727
# Episode 243/500, Total Reward: -11973.97, Loss: 4.990644
# Episode 244/500, Total Reward: -11935.75, Loss: 8.015265
# Episode 245/500, Total Reward: -11902.03, Loss: 3.263960
# Episode 246/500, Total Reward: -11906.02, Loss: 0.238203
# Episode 247/500, Total Reward: -11859.26, Loss: 2.954385
# Episode 248/500, Total Reward: -12005.87, Loss: 15.772786
# Episode 249/500, Total Reward: -11987.66, Loss: 18.889500
# Episode 250/500, Total Reward: -11966.19, Loss: 4.159264
# Episode 251/500, Total Reward: -11881.92, Loss: 11.993114
# Episode 252/500, Total Reward: -11811.87, Loss: 25.892551
# Episode 253/500, Total Reward: -11908.91, Loss: 12.404663
# Episode 254/500, Total Reward: -11878.15, Loss: 10.551095
# Episode 255/500, Total Reward: -11795.82, Loss: 15.541369
# Episode 256/500, Total Reward: -12091.04, Loss: 8.922829
# Episode 257/500, Total Reward: -12051.75, Loss: 11.468386
# Episode 258/500, Total Reward: -11911.21, Loss: 16.786360
# Episode 259/500, Total Reward: -12022.15, Loss: 7.127122
# Episode 260/500, Total Reward: -12085.38, Loss: 6.298157
# Episode 261/500, Total Reward: -11971.66, Loss: 1.695465
# Episode 262/500, Total Reward: -12121.60, Loss: 3.125963
# Episode 263/500, Total Reward: -11977.68, Loss: 0.530130
# Episode 264/500, Total Reward: -11766.89, Loss: 17.991306
# Episode 265/500, Total Reward: -11983.74, Loss: 8.544588
# Episode 266/500, Total Reward: -11923.69, Loss: 10.495137
# Episode 267/500, Total Reward: -11901.92, Loss: 11.848778
# Episode 268/500, Total Reward: -11873.08, Loss: 3.163646
# Episode 269/500, Total Reward: -11955.86, Loss: 0.301639
# Episode 270/500, Total Reward: -11889.70, Loss: 9.829148
# Episode 271/500, Total Reward: -12018.11, Loss: 8.478646
# Episode 272/500, Total Reward: -11933.05, Loss: 12.150143
# Episode 273/500, Total Reward: -12098.10, Loss: 15.382483
# Episode 274/500, Total Reward: -12105.31, Loss: 6.398475
# Episode 275/500, Total Reward: -11797.48, Loss: 2.276010
# Episode 276/500, Total Reward: -11972.20, Loss: 6.994800
# Episode 277/500, Total Reward: -11978.29, Loss: 13.093494
# Episode 278/500, Total Reward: -11933.64, Loss: 15.716175
# Episode 279/500, Total Reward: -11879.61, Loss: 19.509529
# Episode 280/500, Total Reward: -11956.07, Loss: 12.645402
# Episode 281/500, Total Reward: -11963.96, Loss: 8.346071
# Episode 282/500, Total Reward: -11886.91, Loss: 4.799132
# Episode 283/500, Total Reward: -12050.86, Loss: 4.866389
# Episode 284/500, Total Reward: -11799.95, Loss: 4.736993
# Episode 285/500, Total Reward: -11939.92, Loss: 5.095961
# Episode 286/500, Total Reward: -11820.99, Loss: 16.151512
# Episode 287/500, Total Reward: -11962.74, Loss: 8.046636
# Episode 288/500, Total Reward: -11939.24, Loss: 4.843266
# Episode 289/500, Total Reward: -11889.16, Loss: 16.318298
# Episode 290/500, Total Reward: -11872.09, Loss: 3.744663
# Episode 291/500, Total Reward: -11857.20, Loss: 8.752134
# Episode 292/500, Total Reward: -11994.81, Loss: 8.705680
# Episode 293/500, Total Reward: -11985.77, Loss: 13.802488
# Episode 294/500, Total Reward: -11831.36, Loss: 16.901592
# Episode 295/500, Total Reward: -11954.40, Loss: 4.005307
# Episode 296/500, Total Reward: -11909.05, Loss: 5.262568
# Episode 297/500, Total Reward: -11793.35, Loss: 11.513615
# Episode 298/500, Total Reward: -11846.59, Loss: 8.345680
# Episode 299/500, Total Reward: -11885.52, Loss: 11.058517
# Episode 300/500, Total Reward: -11900.09, Loss: 6.281651
# Episode 301/500, Total Reward: -11848.28, Loss: 16.147455
# Episode 302/500, Total Reward: -11858.54, Loss: 7.705996
# Episode 303/500, Total Reward: -11883.83, Loss: 6.027813
# Episode 304/500, Total Reward: -12043.18, Loss: 0.236288
# Episode 305/500, Total Reward: -11900.10, Loss: 18.058153
# Episode 306/500, Total Reward: -11794.96, Loss: 15.295877
# Episode 307/500, Total Reward: -11860.44, Loss: 22.097643
# Episode 308/500, Total Reward: -12041.26, Loss: 26.338707
# Episode 309/500, Total Reward: -11882.15, Loss: 4.081778
# Episode 310/500, Total Reward: -11978.39, Loss: 8.359180
# Episode 311/500, Total Reward: -12180.57, Loss: 6.541143
# Episode 312/500, Total Reward: -12036.22, Loss: 8.317085
# Episode 313/500, Total Reward: -11999.52, Loss: 5.956959
# Episode 314/500, Total Reward: -11973.15, Loss: 3.563123
# Episode 315/500, Total Reward: -12309.24, Loss: 11.021748
# Episode 316/500, Total Reward: -11878.94, Loss: 7.517178
# Episode 317/500, Total Reward: -11921.95, Loss: 12.481886
# Episode 318/500, Total Reward: -12000.98, Loss: 11.274300
# Episode 319/500, Total Reward: -11863.23, Loss: 1.355984
# Episode 320/500, Total Reward: -11992.19, Loss: 8.510118
# Episode 321/500, Total Reward: -11913.52, Loss: 12.376863
# Episode 322/500, Total Reward: -11932.30, Loss: 6.677957
# Episode 323/500, Total Reward: -11786.61, Loss: 4.593939
# Episode 324/500, Total Reward: -11834.29, Loss: 8.358335
# Episode 325/500, Total Reward: -12058.48, Loss: 7.150076
# Episode 326/500, Total Reward: -12081.62, Loss: 14.170595
# Episode 327/500, Total Reward: -11974.98, Loss: 2.808159
# Episode 328/500, Total Reward: -11972.54, Loss: 10.582891
# Episode 329/500, Total Reward: -11911.19, Loss: 3.077874
# Episode 330/500, Total Reward: -11884.85, Loss: 17.950424
# Episode 331/500, Total Reward: -12083.74, Loss: 23.172215
# Episode 332/500, Total Reward: -11861.53, Loss: 9.184562
# Episode 333/500, Total Reward: -12016.40, Loss: 9.981365
# Episode 334/500, Total Reward: -11934.26, Loss: 4.621078
# Episode 335/500, Total Reward: -11901.59, Loss: 8.313053
# Episode 336/500, Total Reward: -12246.29, Loss: 6.804394
# Episode 337/500, Total Reward: -12093.64, Loss: 8.540429
# Episode 338/500, Total Reward: -11817.06, Loss: 4.508077
# Episode 339/500, Total Reward: -11961.83, Loss: 11.558513
# Episode 340/500, Total Reward: -11972.55, Loss: 6.769465
# Episode 341/500, Total Reward: -11893.50, Loss: 11.248514
# Episode 342/500, Total Reward: -11776.38, Loss: 14.705740
# Episode 343/500, Total Reward: -11930.04, Loss: 11.526103
# Episode 344/500, Total Reward: -11907.54, Loss: 7.238475
# Episode 345/500, Total Reward: -11838.04, Loss: 6.468185
# Episode 346/500, Total Reward: -11951.74, Loss: 11.926694
# Episode 347/500, Total Reward: -11818.98, Loss: 11.149249
# Episode 348/500, Total Reward: -11928.34, Loss: 0.409552
# Episode 349/500, Total Reward: -11910.36, Loss: 5.950795
# Episode 350/500, Total Reward: -11984.69, Loss: 9.833912
# Episode 351/500, Total Reward: -11999.99, Loss: 3.421063
# Episode 352/500, Total Reward: -11842.55, Loss: 6.881850
# Episode 353/500, Total Reward: -11851.50, Loss: 4.108026
# Episode 354/500, Total Reward: -11932.79, Loss: 3.845953
# Episode 355/500, Total Reward: -11862.83, Loss: 4.338390
# Episode 356/500, Total Reward: -11962.03, Loss: 16.243673
# Episode 357/500, Total Reward: -11957.94, Loss: 9.522914
# Episode 358/500, Total Reward: -11841.39, Loss: 11.265493
# Episode 359/500, Total Reward: -11858.55, Loss: 4.484862
# Episode 360/500, Total Reward: -11951.50, Loss: 3.047263
# Episode 361/500, Total Reward: -11989.25, Loss: 0.586029
# Episode 362/500, Total Reward: -11876.02, Loss: 10.861924
# Episode 363/500, Total Reward: -11813.41, Loss: 7.401039
# Episode 364/500, Total Reward: -11769.00, Loss: 5.090790
# Episode 365/500, Total Reward: -11916.86, Loss: 8.050340
# Episode 366/500, Total Reward: -11908.43, Loss: 3.423061
# Episode 367/500, Total Reward: -11855.25, Loss: 0.067488
# Episode 368/500, Total Reward: -11894.36, Loss: 4.319580
# Episode 369/500, Total Reward: -11822.59, Loss: 0.934392
# Episode 370/500, Total Reward: -11749.76, Loss: 5.016182
# Episode 371/500, Total Reward: -11833.30, Loss: 5.260343
# Episode 372/500, Total Reward: -11857.16, Loss: 23.260540
# Episode 373/500, Total Reward: -11920.60, Loss: 2.646871
# Episode 374/500, Total Reward: -11857.80, Loss: 8.045440
# Episode 375/500, Total Reward: -11918.94, Loss: 14.256389
# Episode 376/500, Total Reward: -11894.91, Loss: 14.604035
# Episode 377/500, Total Reward: -11856.25, Loss: 6.275496
# Episode 378/500, Total Reward: -11894.76, Loss: 18.668186
# Episode 379/500, Total Reward: -11865.67, Loss: 22.207409
# Episode 380/500, Total Reward: -12017.73, Loss: 11.284878
# Episode 381/500, Total Reward: -11908.05, Loss: 10.359536
# Episode 382/500, Total Reward: -11961.53, Loss: 0.533061
# Episode 383/500, Total Reward: -11859.51, Loss: 8.030842
# Episode 384/500, Total Reward: -11818.84, Loss: 19.095003
# Episode 385/500, Total Reward: -12000.49, Loss: 6.349130
# Episode 386/500, Total Reward: -11907.51, Loss: 5.447621
# Episode 387/500, Total Reward: -11826.42, Loss: 3.391751
# Episode 388/500, Total Reward: -11908.51, Loss: 3.654512
# Episode 389/500, Total Reward: -12074.57, Loss: 13.943332
# Episode 390/500, Total Reward: -11845.01, Loss: 9.184481
# Episode 391/500, Total Reward: -11937.31, Loss: 11.161821
# Episode 392/500, Total Reward: -11927.88, Loss: 10.068473
# Episode 393/500, Total Reward: -12049.05, Loss: 7.873290
# Episode 394/500, Total Reward: -11837.84, Loss: 25.333469
# Episode 395/500, Total Reward: -12008.48, Loss: 11.418188
# Episode 396/500, Total Reward: -11912.79, Loss: 13.026600
# Episode 397/500, Total Reward: -11852.22, Loss: 18.401606
# Episode 398/500, Total Reward: -12032.53, Loss: 5.543398
# Episode 399/500, Total Reward: -12049.29, Loss: 12.710645
# Episode 400/500, Total Reward: -12077.04, Loss: 12.472866
# Episode 401/500, Total Reward: -11858.06, Loss: 5.181150
# Episode 402/500, Total Reward: -11953.52, Loss: 4.374910
# Episode 403/500, Total Reward: -11868.74, Loss: 6.993584
# Episode 404/500, Total Reward: -11979.40, Loss: 0.332064
# Episode 405/500, Total Reward: -11774.03, Loss: 10.684908
# Episode 406/500, Total Reward: -11891.38, Loss: 23.958300
# Episode 407/500, Total Reward: -11895.87, Loss: 12.178483
# Episode 408/500, Total Reward: -12031.26, Loss: 8.987598
# Episode 409/500, Total Reward: -11787.05, Loss: 5.173739
# Episode 410/500, Total Reward: -12068.79, Loss: 9.994551
# Episode 411/500, Total Reward: -11844.50, Loss: 9.458041
# Episode 412/500, Total Reward: -11826.31, Loss: 6.826252
# Episode 413/500, Total Reward: -11900.93, Loss: 4.359692
# Episode 414/500, Total Reward: -11917.48, Loss: 13.763508
# Episode 415/500, Total Reward: -11904.14, Loss: 15.746904
# Episode 416/500, Total Reward: -11867.21, Loss: 6.442672
# Episode 417/500, Total Reward: -11789.68, Loss: 0.821645
# Episode 418/500, Total Reward: -12026.56, Loss: 5.768178
# Episode 419/500, Total Reward: -11929.95, Loss: 12.972960
# Episode 420/500, Total Reward: -11862.85, Loss: 5.382490
# Episode 421/500, Total Reward: -11875.84, Loss: 7.866017
# Episode 422/500, Total Reward: -11881.69, Loss: 17.798777
# Episode 423/500, Total Reward: -11949.76, Loss: 3.830894
# Episode 424/500, Total Reward: -11863.94, Loss: 12.935463
# Episode 425/500, Total Reward: -11904.42, Loss: 12.997909
# Episode 426/500, Total Reward: -11994.63, Loss: 1.633576
# Episode 427/500, Total Reward: -11928.97, Loss: 8.286928
# Episode 428/500, Total Reward: -11908.01, Loss: 0.216116
# Episode 429/500, Total Reward: -11993.26, Loss: 3.982317
# Episode 430/500, Total Reward: -11883.23, Loss: 28.202528
# Episode 431/500, Total Reward: -11819.78, Loss: 8.914839
# Episode 432/500, Total Reward: -11980.35, Loss: 7.804256
# Episode 433/500, Total Reward: -11843.69, Loss: 13.066350
# Episode 434/500, Total Reward: -11975.76, Loss: 12.390808
# Episode 435/500, Total Reward: -11882.48, Loss: 14.293062
# Episode 436/500, Total Reward: -11913.91, Loss: 7.018835
# Episode 437/500, Total Reward: -11851.00, Loss: 17.638773
# Episode 438/500, Total Reward: -11931.59, Loss: 8.501924
# Episode 439/500, Total Reward: -11908.21, Loss: 11.613061
# Episode 440/500, Total Reward: -11873.40, Loss: 3.925465
# Episode 441/500, Total Reward: -11919.22, Loss: 6.371998
# Episode 442/500, Total Reward: -11897.15, Loss: 13.299026
# Episode 443/500, Total Reward: -11767.97, Loss: 10.900623
# Episode 444/500, Total Reward: -11833.11, Loss: 11.393231
# Episode 445/500, Total Reward: -11884.20, Loss: 4.725021
# Episode 446/500, Total Reward: -11825.04, Loss: 4.554375
# Episode 447/500, Total Reward: -11820.72, Loss: 1.877296
# Episode 448/500, Total Reward: -11881.50, Loss: 6.500056
# Episode 449/500, Total Reward: -11900.92, Loss: 8.430211
# Episode 450/500, Total Reward: -11869.35, Loss: 4.274473
# Episode 451/500, Total Reward: -11838.16, Loss: 4.913447
# Episode 452/500, Total Reward: -11972.48, Loss: 6.875087
# Episode 453/500, Total Reward: -11874.23, Loss: 0.834776
# Episode 454/500, Total Reward: -11802.09, Loss: 5.717334
# Episode 455/500, Total Reward: -11879.41, Loss: 6.616519
# Episode 456/500, Total Reward: -11844.08, Loss: 5.809879
# Episode 457/500, Total Reward: -11859.30, Loss: 9.777610
# Episode 458/500, Total Reward: -11958.12, Loss: 5.815022
# Episode 459/500, Total Reward: -11702.56, Loss: 4.737658
# Episode 460/500, Total Reward: -11916.10, Loss: 7.538470
# Episode 461/500, Total Reward: -11910.22, Loss: 7.082522
# Episode 462/500, Total Reward: -12027.53, Loss: 5.074419
# Episode 463/500, Total Reward: -12086.54, Loss: 10.772546
# Episode 464/500, Total Reward: -12132.02, Loss: 5.593451
# Episode 465/500, Total Reward: -12048.07, Loss: 9.284351
# Episode 466/500, Total Reward: -12003.82, Loss: 3.793761
# Episode 467/500, Total Reward: -11904.58, Loss: 5.134607
# Episode 468/500, Total Reward: -12030.39, Loss: 3.692466
# Episode 469/500, Total Reward: -12004.84, Loss: 1.368074
# Episode 470/500, Total Reward: -12096.93, Loss: 2.768354
# Episode 471/500, Total Reward: -11889.24, Loss: 3.306950
# Episode 472/500, Total Reward: -11976.51, Loss: 4.296995
# Episode 473/500, Total Reward: -11797.53, Loss: 6.519029
# Episode 474/500, Total Reward: -12194.29, Loss: 3.167452
# Episode 475/500, Total Reward: -11973.87, Loss: 2.988381
# Episode 476/500, Total Reward: -12008.35, Loss: 3.440297
# Episode 477/500, Total Reward: -11815.36, Loss: 7.637102
# Episode 478/500, Total Reward: -11924.27, Loss: 4.134747
# Episode 479/500, Total Reward: -11961.11, Loss: 0.492849
# Episode 480/500, Total Reward: -11755.71, Loss: 2.233279
# Episode 481/500, Total Reward: -11836.53, Loss: 2.162935
# Episode 482/500, Total Reward: -11871.17, Loss: 5.318230
# Episode 483/500, Total Reward: -11897.20, Loss: 2.010242
# Episode 484/500, Total Reward: -11947.42, Loss: 1.931489
# Episode 485/500, Total Reward: -12001.49, Loss: 1.726613
# Episode 486/500, Total Reward: -11910.87, Loss: 5.456912
# Episode 487/500, Total Reward: -12033.31, Loss: 3.499009
# Episode 488/500, Total Reward: -12403.36, Loss: 3.842905
# Episode 489/500, Total Reward: -11958.10, Loss: 7.964527
# Episode 490/500, Total Reward: -11948.13, Loss: 0.991969
# Episode 491/500, Total Reward: -12074.76, Loss: 3.811434
# Episode 492/500, Total Reward: -12095.66, Loss: 3.114884
# Episode 493/500, Total Reward: -11913.84, Loss: 2.143264
# Episode 494/500, Total Reward: -12162.97, Loss: 5.932720
# Episode 495/500, Total Reward: -11820.36, Loss: 2.778551
# Episode 496/500, Total Reward: -11787.93, Loss: 4.822961
# Episode 497/500, Total Reward: -11910.67, Loss: 1.140419
# Episode 498/500, Total Reward: -11995.78, Loss: 7.602410
# Episode 499/500, Total Reward: -11931.62, Loss: 5.441146
# Episode 500/500, Total Reward: -11974.26, Loss: 4.061686

# %%
import numpy as np

def evaluate_agent(agent, num_episodes=100):
    lap_times = []
    laps_completed = 0
    tire_changes = []

    for episode in range(num_episodes):
        # Reset the environment and agent for a new episode
        track = Track()
        state = track.reset()
        done = False
        lap_time = 0
        changes = 0  # Number of tire changes in the current episode

        while not done:
            # Let the agent choose an action
            action = agent.choose_action(state, epsilon=0)  # Use greedy policy (no exploration)
            #print('action', action)
            reward, next_state, done, velocity = track.transition(action)
            lap_time += (2 * np.pi * track.radius / 8) / velocity

            if done:
                laps_completed += 1
                lap_times.append(lap_time)
            else:
                # Check if a tire change was made
                tire_condition_index = len(track.car.possible_tyres)
                current_tire_condition = next_state[tire_condition_index]
                if current_tire_condition < 0.3:
                    changes += 1

            state = next_state

        tire_changes.append(changes)

    # Calculate performance metrics
    average_lap_time = np.mean(lap_times)
    laps_per_episode = np.mean(laps_completed)
    average_tire_changes = np.mean(tire_changes)

    print(f"Average Lap Time: {average_lap_time} seconds")
    print(f"Average Laps Completed: {laps_per_episode} out of 162 laps")
    print(f"Average Tire Changes: {average_tire_changes} per episode")

# Create and initialize the agent
agent = Agent(state_dim = 13, action_dim = 5, hidden_dim=128)
# Load the trained agent's model weights (if available)

# Evaluate the agent's performance
evaluate_agent(agent, num_episodes=100)
# Out:
# Average Lap Time: 36928.869139224546 seconds
# Average Laps Completed: 100.0 out of 162 laps
# Average Tire Changes: 1239.75 per episode
